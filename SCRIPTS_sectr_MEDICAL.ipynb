# %% [markdown]
# # code pour sectr MEDICAL

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://annumed.sante-dz.com/"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="fr">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# website: http://ogp.me/ns/website#">
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <link href="https://res.cloudinary.com" rel="dns-prefetch"/>
# <link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/>
# <link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="B544A211687FB8DC5247ECDE28E588F5" name="msvalidate.01"/>
# <meta content="" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="https://annumed.sante-dz.com" property="og:url"/>
# <meta content="https://annumed.sante-dz.com" name="twitter:site"/>
# <meta content="V4uTDsfwNO9APqb2Jwqtdeffv2jkUiDWClarF1oj" name="csrf-token"/>
# <meta content="#760b5c" name="theme-color"/>
# <!--<link rel="icon" sizes="192x192" href="nice-highres.png">-->
# ...

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://annumed.sante-dz.com/annuaire'

response = requests.get(URL)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    # Trouver tous les éléments "h3" dans la page
    h3_elements = soup.find_all('h3')
    
    # Extraire le texte des éléments "h3" et les stocker dans une liste
    reviews_text = [h3.text.strip() for h3 in h3_elements]

    # Imprimer les avis
    for index, review_text in enumerate(reviews_text, 1):
        print(f"Review {index}: {review_text}")
else:
    print(f"La requête a échoué avec le code d'état : {response.status_code}")
# Out:
# Review 1: Mahalli
# Review 2: DR BENHAMIDA ADNANE
# Review 3: Cabinet d'ophtalmologie dr boudoucha amine
# Review 4: CGSA Clinique Gestion du Stress et de l'Anxiété
# Review 5: Dr BENDADA MOHAMMED
# Review 6: Bouzid Arbaoui
# Review 7: medecin de garde
# Review 8: Wahida CHOUITI
# Review 9: Maimour .A ep Bouyoucef
# Review 10: Laboratoire d'Analyses Médicales El Hanaa
# Review 11: Trouvez un Professionnel
# Review 12: Conseils
# Review 13: Actualités
# Review 14: A la une
# Review 15: Partenaires
# Review 16: Nos sites associés
# Review 17: Récemment mise à jour
# Review 18: Contact
# Review 19: Réseaux sociaux

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = "https://annumed.sante-dz.com/annuaire"
soup = BeautifulSoup(requests.get(url).content, "html.parser")

data = []
for i in soup.select(".info:has(header)"):
    name = i.h3.text
    spec = i.select_one("header p").text
    cats = [s.text for s in i.select(".speciliate")]
    addr = i.select_one(".address__wrapper").get_text(strip=True, separator=" ")
    data.append((name, spec, ",".join(cats), addr))

df = pd.DataFrame(data, columns=["Name", "Spec", "Categories", "Address"])
print(df)
# Out:
#                                               Name                   Spec  \
# 0                                          Mahalli                Médecin
# 1                              DR BENHAMIDA ADNANE                Médecin
# 2       Cabinet d'ophtalmologie dr boudoucha amine                Médecin
# 3  CGSA Clinique Gestion du Stress et de l'Anxiété               Clinique
# 4                              Dr BENDADA MOHAMMED                Médecin
# 5                                   Bouzid Arbaoui                Médecin
# 6                                 medecin de garde               Clinique
# 7                                   Wahida CHOUITI                Médecin
# 8                          Maimour .A ep Bouyoucef                Médecin
# 9       Laboratoire d'Analyses Médicales El Hanaa   Laboratoire d'Analyse
#
#                                           Categories  \
# 0                                  Médecine Générale
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

data = []
for page in range(1, 10):   # <-- increase number of pages here
    print("Page", page)
    url = f"https://annumed.sante-dz.com/annuaire?page={page}"
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for i in soup.select(".info:has(header)"):
        name = i.h3.text
        spec = i.select_one("header p").text
        cats = [s.text for s in i.select(".speciliate")]
        addr = i.select_one(".address__wrapper").get_text(strip=True, separator=" ")
        data.append((name, spec, ",".join(cats), addr))

df = pd.DataFrame(data, columns=["Name", "Spec", "Categories", "Address"])
print(df)
# Out:
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
#                                                Name         Spec  \
# 0                                           Mahalli      Médecin
# 1                               DR BENHAMIDA ADNANE      Médecin
# 2        Cabinet d'ophtalmologie dr boudoucha amine      Médecin
# 3   CGSA Clinique Gestion du Stress et de l'Anxiété     Clinique
# 4                               Dr BENDADA MOHAMMED      Médecin
# ..                                              ...          ...
# 85                                   Moussa djamila      Médecin
# 86                        Cabinet vétérinaire 3 cma  Vétérinaire
# 87                                   Benaissa lilia      Médecin
# 88                                 Benhenni yasmine    Pharmacie
# 89                                   Akkouche sarah      Médecin
#
#                                            Categories  \
# ...

# %% [markdown]
# # FINAL RIGHT CODE

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

data = []
for page in range(1, 100):   # <-- increase number of pages here
    print("Page", page)
    url = f"https://annumed.sante-dz.com/annuaire?page={page}"
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for i in soup.select(".info:has(header)"):
        name = i.h3.text
        spec = i.select_one("header p").text
        cats = [s.text for s in i.select(".speciliate")]
        addr = i.select_one(".address__wrapper").get_text(strip=True, separator=" ")
        data.append((name, spec, ",".join(cats), addr))

df = pd.DataFrame(data, columns=["Name", "Spec", "Categories", "Address"])

# Define the file path for the Excel file
excel_file_path = r"C:\Users\LENOVO\Desktop\scraping_sante\results.xlsx"

# Save the DataFrame to an Excel file
df.to_excel(excel_file_path, index=False)
print("Data saved to Excel:", excel_file_path)
# Out:
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# Page 11
# Page 12
# Page 13
# Page 14
# Page 15
# Page 16
# Page 17
# Page 18
# Page 19
# Page 20
# Page 21
# Page 22
# Page 23
# Page 24
# Page 25
# Page 26
# Page 27
# Page 28
# Page 29
# Page 30
# Page 31
# Page 32
# Page 33
# Page 34
# Page 35
# Page 36
# Page 37
# Page 38
# Page 39
# Page 40
# Page 41
# Page 42
# Page 43
# Page 44
# Page 45
# Page 46
# Page 47
# Page 48
# Page 49
# Page 50
# Page 51
# Page 52
# Page 53
# Page 54
# Page 55
# Page 56
# Page 57
# Page 58
# Page 59
# Page 60
# Page 61
# Page 62
# Page 63
# Page 64
# Page 65
# Page 66
# Page 67
# Page 68
# Page 69
# Page 70
# Page 71
# Page 72
# Page 73
# Page 74
# Page 75
# Page 76
# Page 77
# Page 78
# Page 79
# Page 80
# Page 81
# Page 82
# Page 83
# Page 84
# Page 85
# Page 86
# Page 87
# Page 88
# Page 89
# Page 90
# Page 91
# Page 92
# Page 93
# Page 94
# Page 95
# Page 96
# Page 97
# Page 98
# Page 99
# ...
